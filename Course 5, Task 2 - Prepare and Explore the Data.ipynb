# %%
import pandas as pd

# %%
credit = pd.read_csv('default of credit card clients.csv', header = 1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
#Remove the column 'ID' from the dataframe
credit.drop(columns = 'ID')
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# 5          50000    1          1         2   37      0      0      0      0
# 6         500000    1          1         2   29      0      0      0      0
# 7         100000    2          2         2   23      0     -1     -1      0
# 8         140000    2          3         1   28      0      0      2      0
# 9          20000    1          3         2   35     -2     -2     -2     -2
# 10        200000    2          3         2   34      0      0      2      0
# ...

# %%
#Check for missing Values
credit.isnull().values.any()
# Out:
# False

# %%
#Change to nominal/categorical data type
credit["SEX"] = credit["SEX"].astype('category')
credit["EDUCATION"] = credit["EDUCATION"].astype('category')
credit["MARRIAGE"] = credit["MARRIAGE"].astype('category')
credit[['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']] = credit[['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']].astype('category')
credit['default payment next month'] = credit['default payment next month'].astype('category')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null category
# EDUCATION                     30000 non-null category
# MARRIAGE                      30000 non-null category
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null category
# PAY_2                         30000 non-null category
# PAY_3                         30000 non-null category
# PAY_4                         30000 non-null category
# PAY_5                         30000 non-null category
# PAY_6                         30000 non-null category
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
#Discretize age, group into 10 bins
pd.cut(credit['AGE'], 8)
# Out:
# 0        (20.942, 28.25]
# 1        (20.942, 28.25]
# 2          (28.25, 35.5]
# 3          (35.5, 42.75]
# 4          (50.0, 57.25]
# 5          (35.5, 42.75]
# 6          (28.25, 35.5]
# 7        (20.942, 28.25]
# 8        (20.942, 28.25]
# 9          (28.25, 35.5]
# 10         (28.25, 35.5]
# 11         (50.0, 57.25]
# 12         (35.5, 42.75]
# 13         (28.25, 35.5]
# 14         (28.25, 35.5]
# 15       (20.942, 28.25]
# 16       (20.942, 28.25]
# 17         (42.75, 50.0]
# 18         (42.75, 50.0]
# 19         (28.25, 35.5]
# 20         (35.5, 42.75]
# 21         (35.5, 42.75]
# 22       (20.942, 28.25]
# 23         (35.5, 42.75]
# 24       (20.942, 28.25]
# 25       (20.942, 28.25]
# 26       (20.942, 28.25]
# 27         (28.25, 35.5]
# 28         (42.75, 50.0]
# 29       (20.942, 28.25]
#               ...
# 29970      (28.25, 35.5]
# 29971      (35.5, 42.75]
# 29972      (35.5, 42.75]
# 29973      (28.25, 35.5]
# 29974      (35.5, 42.75]
# 29975      (35.5, 42.75]
# ...

# %%
#Save updated dataframe as a csv
credit.to_csv('default updated.csv')

# %%
credit = pd.read_csv('default updated.csv', header = 0)

# %%
#Print the column names of the dataframe
header = credit.dtypes.index
print(header)
# Out:
# Index(['Unnamed: 0', 'ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1',
#        'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
#        'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Histogram for limit_bal, number of bins not specified 
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
#Histogram for limit_bal, with 4 bins
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['LIMIT_BAL'], bins=8)
# Out:
# (array([1.4541e+04, 8.7420e+03, 4.4680e+03, 2.0430e+03, 1.4700e+02,
#         5.3000e+01, 5.0000e+00, 1.0000e+00]),
#  array([  10000.,  133750.,  257500.,  381250.,  505000.,  628750.,
#          752500.,  876250., 1000000.]),
#  <a list of 8 Patch objects>)

# %%
plt.hist(credit['AGE'], bins = 8)
# Out:
# (array([8013., 8796., 6535., 3976., 2136.,  434.,   98.,   12.]),
#  array([21.  , 28.25, 35.5 , 42.75, 50.  , 57.25, 64.5 , 71.75, 79.  ]),
#  <a list of 8 Patch objects>)

# %%
plt.hist(credit['BILL_AMT1'], bins = 8)
# Out:
# (array([2.0000e+00, 2.5977e+04, 3.2400e+03, 6.0600e+02, 1.5100e+02,
#         2.2000e+01, 1.0000e+00, 1.0000e+00]),
#  array([-165580.   ,  -24318.625,  116942.75 ,  258204.125,  399465.5  ,
#          540726.875,  681988.25 ,  823249.625,  964511.   ]),
#  <a list of 8 Patch objects>)

# %%
plt.hist(credit['PAY_AMT1'], bins = 8)
# Out:
# (array([2.988e+04, 8.600e+01, 2.800e+01, 3.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([     0., 109194., 218388., 327582., 436776., 545970., 655164.,
#         764358., 873552.]),
#  <a list of 8 Patch objects>)

# %%
#Line plot
plt.plot(credit['LIMIT_BAL'])
plt.show()
#There are a couple of outliers that are apparent.

# %%
plt.plot(credit['AGE'])
plt.show()

# %%
plt.plot(credit['BILL_AMT1'])
plt.show()
#Bill amount 1 is much higher than payment amount 1

# %%
plt.plot(credit['PAY_AMT1'])
plt.show()

# %%
#Scatter plot, must first set features equal to variables
x = credit['PAY_0']
y = credit['PAY_2']

# %%
#Create scatter plot between the two variables
plt.scatter(x,y)
plt.show()

# %%
x1 = credit['AGE']
y1 = credit['BILL_AMT1']

# %%
plt.scatter(x1,y1)
plt.show()

# %%
x2 = credit['AGE']
y2 = credit['PAY_AMT2']

# %%
plt.scatter(x2,y2)
plt.show()

# %%
#The bill amount appears higher than the amt that was paid. Both bill amt and payment amt are more densely packed to the
#left

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
#Looks like the median for bill amt 1 is near 0, there must be a large amount of negative data points that is causing this
#to be skewed

# %%
A = credit['AGE']
plt.boxplot(A,0,'gD')
plt.show()

# %%
#The median age is around 35
#The range looks like 22-60
#The green dots represent the outliers, there appears to be quite a few outliers within age, mostly the older ages

# %%
#Basic correlation coefficient matrix
corrMatrix = credit.corr()
print(corrMatrix)
# Out:
#                             Unnamed: 0        ID  LIMIT_BAL       SEX  \
# Unnamed: 0                    1.000000  1.000000   0.026179  0.018497
# ID                            1.000000  1.000000   0.026179  0.018497
# LIMIT_BAL                     0.026179  0.026179   1.000000  0.024755
# SEX                           0.018497  0.018497   0.024755  1.000000
# EDUCATION                     0.039177  0.039177  -0.219161  0.014232
# MARRIAGE                     -0.029079 -0.029079  -0.108139 -0.031389
# AGE                           0.018678  0.018678   0.144713 -0.090874
# PAY_0                        -0.030575 -0.030575  -0.271214 -0.057643
# PAY_2                        -0.011215 -0.011215  -0.296382 -0.070771
# PAY_3                        -0.018494 -0.018494  -0.286123 -0.066096
# PAY_4                        -0.002735 -0.002735  -0.267460 -0.060173
# PAY_5                        -0.022199 -0.022199  -0.249411 -0.055064
# ...

# %%
#bill amount 4 is highly correlated with the other bill amounts, this makes sense because most likely customers
#will have similar bill amount from month to month (or whatever time period)

# %%
covMatrix = credit.cov()
print(covMatrix)
# Out:
#                               Unnamed: 0            ID     LIMIT_BAL  \
# Unnamed: 0                  7.500250e+07  7.500250e+07  2.941664e+07
# ID                          7.500250e+07  7.500250e+07  2.941664e+07
# LIMIT_BAL                   2.941664e+07  2.941664e+07  1.683446e+10
# SEX                         7.835638e+01  7.835638e+01  1.571051e+03
# EDUCATION                   2.681543e+02  2.681543e+02 -2.247403e+04
# MARRIAGE                   -1.314525e+02 -1.314525e+02 -7.323670e+03
# AGE                         1.491057e+03  1.491057e+03  1.730767e+05
# PAY_0                      -2.975726e+02 -2.975726e+02 -3.954593e+04
# PAY_2                      -1.162770e+02 -1.162770e+02 -4.603765e+04
# PAY_3                      -1.916922e+02 -1.916922e+02 -4.443225e+04
# PAY_4                      -2.769132e+01 -2.769132e+01 -4.057181e+04
# PAY_5                      -2.178600e+02 -2.178600e+02 -3.667056e+04
# PAY_6                      -2.018774e+02 -2.018774e+02 -3.509308e+04
# ...

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import all the necessary libraries

# %%
credit.head()
# Out:
#    Unnamed: 0  ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 0           0   1      20000    2          2         1   24      2      2
# 1           1   2     120000    2          2         2   26     -1      2
# 2           2   3      90000    2          2         2   34      0      0
# 3           3   4      50000    2          2         1   37      0      0
# 4           4   5      50000    1          2         1   57     -1      0
#
#    PAY_3             ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# 0     -1             ...                      0          0          0
# 1      0             ...                   3272       3455       3261
# 2      0             ...                  14331      14948      15549
# 3      0             ...                  28314      28959      29547
# 4     -1             ...                  20940      19146      19131
#
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
credit.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1',
#        'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
#        'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 26 columns):
# Unnamed: 0                    30000 non-null int64
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# ...

# %%
#find the number of customers in each age group
credit.groupby('AGE')['AGE'].count()
# Out:
# AGE
# 21      67
# 22     560
# 23     931
# 24    1127
# 25    1186
# 26    1256
# 27    1477
# 28    1409
# 29    1605
# 30    1395
# 31    1217
# 32    1158
# 33    1146
# 34    1162
# 35    1113
# 36    1108
# 37    1041
# 38     944
# 39     954
# 40     870
# 41     824
# 42     794
# 43     670
# 44     700
# 45     617
# 46     570
# 47     501
# 48     466
# 49     452
# 50     411
# 51     340
# 52     304
# 53     325
# 54     247
# 55     209
# 56     178
# 57     122
# 58     122
# 59      83
# 60      67
# 61      56
# 62      44
# 63      31
# 64      31
# 65      24
# 66      25
# 67      16
# 68       5
# 69      15
# 70      10
# 71       3
# 72       3
# 73       4
# 74       1
# 75       3
# 79       1
# Name: AGE, dtype: int64

# %%
#age 29 has the most customers, there are 1605 customers who are 29
#The next most frequent age is 27
#most customers fall within 23-39

# %%
credit.groupby('EDUCATION')['EDUCATION'].count()
# Out:
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: EDUCATION, dtype: int64

# %%
#most customers, 14030, fall under the 2 category for education, university
#10585 customers are in graduate school

# %%
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# 1    11888
# 2    18112
# Name: SEX, dtype: int64

# %%
#majority of customers are female, 60.4% are female and 39.6% are male

# %%
credit.groupby('MARRIAGE')['MARRIAGE'].count()
# Out:
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# Name: MARRIAGE, dtype: int64

# %%
#majority of customers are single (53.2%), 45.5% are married, and 1.08% are divorced

# %%
fg = sns.factorplot('SEX', data=credit, kind='count', aspect=1.5)
fg.set_xlabels('SEX')

# %%
#seaborn, similar to groupby but shown as a visual

# %%
credit.groupby(['SEX', 'EDUCATION'])['SEX'].count()
# Out:
# SEX  EDUCATION
# 1    0               8
#      1            4354
#      2            5374
#      3            1990
#      4              42
#      5              95
#      6              25
# 2    0               6
#      1            6231
#      2            8656
#      3            2927
#      4              81
#      5             185
#      6              26
# Name: SEX, dtype: int64

# %%
# majority of both males and females have a university education, seems to be a similar education bw males/females

# %%
credit.groupby(['SEX', 'default payment next month'])['SEX'].count()
# Out:
# SEX  default payment next month
# 1    0                              9015
#      1                              2873
# 2    0                             14349
#      1                              3763
# Name: SEX, dtype: int64

# %%
#similar breakdown bw male and female and whether or not they defaulted
# females, 79.2% did NOT default and 20.8% defaulted
# males, 75.8% did NOT default and 24.2% defaulted 
# females had a slightly lower percentage that defaulted (3.4%)

# %%
credit.groupby(['EDUCATION', 'default payment next month'])['EDUCATION'].count()
# Out:
# EDUCATION  default payment next month
# 0          0                                14
# 1          0                              8549
#            1                              2036
# 2          0                             10700
#            1                              3330
# 3          0                              3680
#            1                              1237
# 4          0                               116
#            1                                 7
# 5          0                               262
#            1                                18
# 6          0                                43
#            1                                 8
# Name: EDUCATION, dtype: int64

# %%
# grad school (1), 80.8% no default, 19.2% default
# university (2), 76.3% no default, 23.7% default
# high school (3), 74.8% no default, 25.2% default
# the less education the higher the percentage of customers that defaulted

# %%
credit.groupby(['MARRIAGE', 'default payment next month'])['MARRIAGE'].count()
# Out:
# MARRIAGE  default payment next month
# 0         0                                49
#           1                                 5
# 1         0                             10453
#           1                              3206
# 2         0                             12623
#           1                              3341
# 3         0                               239
#           1                                84
# Name: MARRIAGE, dtype: int64

# %%
# single customers had the lowest percentage default (20.9%)
# divorced customers had the highest percentage default (26%)

# %%
g = sns.factorplot('AGE', data=credit, hue='default payment next month', kind='count', aspect=1.75)
g.set_xlabels('AGE')

# %%
g = sns.factorplot('SEX', data=credit, hue='default payment next month', kind='count', aspect=1.75)
g.set_xlabels('SEX')

# %%
g = sns.factorplot('EDUCATION', data=credit, hue='default payment next month', kind='count', aspect=1.75)
g.set_xlabels('EDUCATION')

# %%
credit.pivot_table('default payment next month', 'SEX', 'EDUCATION', aggfunc=np.sum, margins=True)
# Out:
# EDUCATION  0     1     2     3  4   5  6   All
# SEX
# 1          0   906  1408   545  4   6  4  2873
# 2          0  1130  1922   692  3  12  4  3763
# All        0  2036  3330  1237  7  18  8  6636

# %%
# above is showing the customers who defaulted organized by sex and education level

# %%
credit.SEX.describe()
# Out:
# count    30000.000000
# mean         1.603733
# std          0.489129
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          2.000000
# Name: SEX, dtype: float64

# %%
credit.AGE.describe()
# Out:
# count    30000.000000
# mean        35.485500
# std          9.217904
# min         21.000000
# 25%         28.000000
# 50%         34.000000
# 75%         41.000000
# max         79.000000
# Name: AGE, dtype: float64

# %%
credit.LIMIT_BAL.describe()
# Out:
# count      30000.000000
# mean      167484.322667
# std       129747.661567
# min        10000.000000
# 25%        50000.000000
# 50%       140000.000000
# 75%       240000.000000
# max      1000000.000000
# Name: LIMIT_BAL, dtype: float64

# %%
age = credit['AGE'].dropna()
age_dist = sns.distplot(age)
age_dist.set_title("Distribution of Customers' Ages")
# Out:
# C:\Users\emman\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,"Distribution of Customers' Ages")

# %%
credit['AGE'].hist(bins=50)

# %%
fig = sns.FacetGrid(credit, hue='SEX', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Gender')
fig.add_legend()

# %%
fig = sns.FacetGrid(credit, hue='EDUCATION', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
sns.factorplot('EDUCATION','default payment next month', hue='SEX', data=credit, order=range(1,4))

# %%
#The graph aboves shows that as the customer decreases the amount of education they receive the probability that
# they will default goes up
#There is a higher percentage for males then females

# %%
sns.factorplot('MARRIAGE','default payment next month', hue='SEX', data=credit, order=range(1,4))

# %%
sns.lmplot('AGE', 'default payment next month', data=credit)

# %%
#from above, doesn't seem to be much of a linear relationship between age and default

# %%
sns.lmplot('EDUCATION', 'default payment next month', data=credit)

# %%
#slight positive linear relationship bw education and default on payment
# as education is less chances of default increases (but only slightly)
